# %%
presentes = [
    {
        "id": 1,
        "nome": "Vale Pizza para Noites Preguiçosas",
        "preco": 59.90,
        "imagem": "images/vale_pizza.jpg",
        "descricao": "Porque nem todo jantar precisa ser gourmet."
    },
    {
        "id": 2,
        "nome": "Kit Sobrevivência para o Casamento",
        "preco": 79.90,
        "imagem": "images/kit_sobrevivencia.jpg",
        "descricao": "Contém café, chocolate e paciência (item essencial)."
    },
    {
        "id": 3,
        "nome": "Almofadas Decorativas Engraçadas",
        "preco": 89.90,
        "imagem": "images/almofadas.jpg",
        "descricao": "Para decorar a casa e render boas risadas."
    },
    {
        "id": 4,
        "nome": "Relógio de Parede Retrô",
        "preco": 99.90,
        "imagem": "images/relogio.jpg",
        "descricao": "Para lembrar que o tempo voa quando estamos juntos."
    },
    {
        "id": 5,
        "nome": "Panela de Arroz Elétrica",
        "preco": 119.33,
        "imagem": "images/panela_arroz.jpg",
        "descricao": "Arroz soltinho garantido no dia a dia."
    },
    {
        "id": 6,
        "nome": "Jogo de Copos Personalizados",
        "preco": 129.90,
        "imagem": "images/copos_personalizados.jpg",
        "descricao": "Para evitar a clássica pergunta: esse copo é meu?"
    },
    {
        "id": 7,
        "nome": "Aspirador de Pó Portátil",
        "preco": 159.90,
        "imagem": "images/aspirador.jpg",
        "descricao": "Porque amor também é dividir a faxina."
    },
    {
        "id": 8,
        "nome": "Jogo de Taças para Vinho",
        "preco": 149.90,
        "imagem": "images/tacas_vinho.jpg",
        "descricao": "Para brindar cada conquista a dois."
    },
    {
        "id": 9,
        "nome": "Kit Fondue Romântico",
        "preco": 179.90,
        "imagem": "images/fondue.jpg",
        "descricao": "Para noites frias e corações quentinhos."
    },
    {
        "id": 10,
        "nome": "Cafeteira Elétrica",
        "preco": 189.90,
        "imagem": "images/cafeteira.jpg",
        "descricao": "Combustível oficial das manhãs felizes."
    },
    {
        "id": 11,
        "nome": "Máquina de Macarrão e Massas Caseiras",
        "preco": 229.02,
        "imagem": "images/maquina_macarrao.jpg",
        "descricao": "Massa artesanal feita com amor."
    },
    {
        "id": 12,
        "nome": "Liquidificador Potente",
        "preco": 249.90,
        "imagem": "images/liquidificador.jpg",
        "descricao": "Para sucos, vitaminas e receitas improvisadas."
    },
    {
        "id": 13,
        "nome": "Jogo de Cama Queen Conforto Premium",
        "preco": 299.90,
        "imagem": "images/jogo_cama.jpg",
        "descricao": "Noites tranquilas e sonhos compartilhados."
    },
    {
        "id": 14,
        "nome": "Fritadeira Elétrica sem Óleo (Air Fryer)",
        "preco": 399.90,
        "imagem": "images/airfryer.jpg",
        "descricao": "Crocância sem culpa para o casal."
    },
    {
        "id": 15,
        "nome": "Jogo de Panelas Completo",
        "preco": 499.90,
        "imagem": "images/jogo_panelas.jpg",
        "descricao": "A base de toda cozinha feliz."
    },
    {
        "id": 16,
        "nome": "Micro-ondas Compacto",
        "preco": 599.90,
        "imagem": "images/microondas.jpg",
        "descricao": "Praticidade para o dia a dia."
    },
    {
        "id": 17,
        "nome": "Aparelho de Jantar Completo",
        "preco": 699.90,
        "imagem": "images/aparelho_jantar.jpg",
        "descricao": "Para receber amigos e família com carinho."
    },
    {
        "id": 18,
        "nome": "Smart Speaker com Assistente Virtual",
        "preco": 799.90,
        "imagem": "images/smart_speaker.jpg",
        "descricao": "Para música, lembretes e boas risadas."
    },
    {
        "id": 19,
        "nome": "Adega Climatizada para Vinhos",
        "preco": 899.90,
        "imagem": "images/adega.jpg",
        "descricao": "Porque alguns vinhos merecem cuidado especial."
    },
    {
        "id": 20,
        "nome": "Vale Lua de Mel (Cota Especial)",
        "preco": 999.90,
        "imagem": "images/lua_mel.jpg",
        "descricao": "Para criar memórias inesquecíveis."
    }
]
